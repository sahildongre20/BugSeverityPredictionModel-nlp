# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
import pandas as pd

# %%
# df = pd.read_csv('bug_data.csv')
df = pd.read_csv('bug_data.csv')
df.head()
# Out:
#     id                                        description severity
# 0   91               document properties cannot be listed    major
# 1  103   layout bug: table cell overflows containing cell   normal
# 2  104    table saved as text: missing inter-column space    minor
# 3  105  nested <TABLE>s: bgcolor of inner table not re...   normal
# 4  133  Navigator draws entities like &lt;&amp;&gt; as...    minor

# %%
df.head()
df.dropna(inplace=True)

# %%
#0.to lowercase
def convert_description_to_lowercase(df):
    # Create a copy of the DataFrame to avoid modifying the original
    modified_df = df.copy()
    
    # Convert the text in the 'description' column to lowercase
    modified_df['description'] = modified_df['description'].str.lower()
    
    return modified_df

# %%
df_wrn = convert_description_to_lowercase(df)
df_wrn.head(10)
# Out:
#     id                                        description  severity
# 0   91               document properties cannot be listed     major
# 1  103   layout bug: table cell overflows containing cell    normal
# 2  104    table saved as text: missing inter-column space     minor
# 3  105  nested <table>s: bgcolor of inner table not re...    normal
# 4  133  navigator draws entities like &lt;&amp;&gt; as...     minor
# 5  134  navigator crashes w/ javascript setting textar...  critical
# 6  159                  warning fix : ns/js/jsj/jsstubs.c   trivial
# 7  174  failed assert on exit at mkgeturl.c:5855 (net_...     minor
# 8  213             showdocument("javascript:..."); broken     major
# 9  220  incorrect display of cp-1250 pages in unix ver...    normal

# %%
    df_wrn["description"] = df["description"].apply(lambda x: re.sub(r'[^\w\s]', '', x) if x else x)

# %%
df_wrn.head(10)
# Out:
#     id                                        description  severity
# 0   91               document properties cannot be listed     major
# 1  103    layout bug table cell overflows containing cell    normal
# 2  104      table saved as text missing intercolumn space     minor
# 3  105  nested TABLEs bgcolor of inner table not recog...    normal
# 4  133  Navigator draws entities like ltampgt as s whe...     minor
# 5  134  Navigator crashes w javascript setting textare...  critical
# 6  159                       warning fix  nsjsjsjjsStubsc   trivial
# 7  174  Failed assert on exit at mkgeturlc5855 net_Cle...     minor
# 8  213                      showDocumentjavascript broken     major
# 9  220  Incorrect display of CP1250 pages in Unix version    normal

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

# Define the Naive Bayes classifier
naive_bayes = MultinomialNB()

# Define the SVM classifier
svm = SVC()

# Define the feature extraction step (e.g., CountVectorizer)
vectorizer = CountVectorizer()

# Fit and transform the input data using the vectorizer
X_train_vectorized = vectorizer.fit_transform(X_train)

# Fit the Naive Bayes classifier to the vectorized data
naive_bayes.fit(X_train_vectorized, y_train)

# Extract the probabilities estimated by Naive Bayes
probs = naive_bayes.predict_proba(X_train_vectorized)

# Concatenate the probabilities with the original input data
X_train_with_probs = np.concatenate([X_train_vectorized.toarray(), probs], axis=1)

# Fit the SVM classifier to the data with Naive Bayes probabilities as features
svm.fit(X_train_with_probs, y_train)

# Transform the test data using the vectorizer
X_test_vectorized = vectorizer.transform(X_test)

# Extract the probabilities estimated by Naive Bayes for the test data
probs_test = naive_bayes.predict_proba(X_test_vectorized)

# Concatenate the probabilities with the test data
X_test_with_probs = np.concatenate([X_test_vectorized.toarray(), probs_test], axis=1)

# Make predictions using the SVM classifier
y_pred = svm.predict(X_test_with_probs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [82], line 20
#      17 X_train_vectorized = vectorizer.fit_transform(X_train)
#      19 # Fit the Naive Bayes classifier to the vectorized data
# ---> 20 naive_bayes.fit(X_train_vectorized, y_train)
#      22 # Extract the probabilities estimated by Naive Bayes
#      23 probs = naive_bayes.predict_proba(X_train_vectorized)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/naive_bayes.py:749, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     729 """Fit Naive Bayes classifier according to X, y.
#     730
#     731 Parameters
#    (...)
#     746     Returns the instance itself.
#     747 """
#     748 self._validate_params()
# --> 749 X, y = self._check_X_y(X, y)
#     750 _, n_features = X.shape
#     752 labelbin = LabelBinarizer()
#
# ...

# %%
import pandas as pd
import re
# !pip install textblob
from textblob import TextBlob


df = pd.read_csv("bug_data.csv")
df.head()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in /home/pratik/.local/lib/python3.10/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /home/pratik/.local/lib/python3.10/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: joblib in /home/pratik/.local/lib/python3.10/site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/pratik/.local/lib/python3.10/site-packages (from nltk>=3.1->textblob) (2022.10.31)
# Requirement already satisfied: tqdm in /home/pratik/.local/lib/python3.10/site-packages (from nltk>=3.1->textblob) (4.65.0)
#     id                                        description severity
# 0   91               document properties cannot be listed    major
# 1  103   layout bug: table cell overflows containing cell   normal
# 2  104    table saved as text: missing inter-column space    minor
# 3  105  nested <TABLE>s: bgcolor of inner table not re...   normal
# 4  133  Navigator draws entities like &lt;&amp;&gt; as...    minor

# %%
#cleaning the data but how ? 
#0.convert to lowercase
#1. remove numbers from the data
#2.remove single word reports
#3.run a spell check thingy

# %%
# df = df[df['severity'] != 'normal']
df = df[df['severity'] != 'enhancement']
# df = df[df['severity'] != 'normal']

# %%
#0.to lowercase
def convert_description_to_lowercase(df):
    # Create a copy of the DataFrame to avoid modifying the original
    modified_df = df.copy()
    
    # Convert the text in the 'description' column to lowercase
    modified_df['description'] = modified_df['description'].str.lower()
    
    return modified_df

# %%
grouped = df.groupby('severity')
sampled_df = pd.DataFrame()

for name, group in grouped:
    sampled_group = group.sample(n=round(60000/len(grouped)), random_state=42 , replace=True)
    sampled_df = pd.concat([sampled_df, sampled_group])

sampled_df.reset_index(drop=True, inplace=True)


df_wrn = convert_description_to_lowercase(sampled_df)
df_wrn.head(10)
# Out:
#        id                                        description severity
# 0  460484       spam email with euro symbol crashes shredder  blocker
# 1  673043  the token you submitted does not exist , has e...  blocker
# 2   65661               xpcom plugin instances not destroyed  blocker
# 3  112215  embedding aps (mfcembed & testgtkembed) crashi...  blocker
# 4   92460  testgtkembed missing scroll bars and key based...  blocker
# 5   88994           crashes after the splash screen on win2k  blocker
# 6  418648  configure changes required for building on win...  blocker
# 7  159243  move fontencoding.properties in a sharable loc...  blocker
# 8  230183  preprocessor.pl not executed correctly in /too...  blocker
# 9   31804  open up another window/location while download...  blocker

# %%
#1.removing numbers from the data
import re
import pandas as pd

def remove_numbers_from_description(df):
    # Create a copy of the DataFrame to avoid modifying the original
    modified_df = df.copy()
    
    # Convert non-string values to strings
    modified_df['description'] = modified_df['description'].apply(lambda x: str(x))
    
    # Remove any digits from the description column
    modified_df['description'] = modified_df['description'].apply(lambda x: re.sub(r'\d+', '', x))
    
    return modified_df

# %%
 
df_wrn = remove_numbers_from_description(df_wrn)
df_wrn.head(10)
# Out:
#        id                                        description severity
# 0  460484       spam email with euro symbol crashes shredder  blocker
# 1  673043  the token you submitted does not exist , has e...  blocker
# 2   65661               xpcom plugin instances not destroyed  blocker
# 3  112215  embedding aps (mfcembed & testgtkembed) crashi...  blocker
# 4   92460  testgtkembed missing scroll bars and key based...  blocker
# 5   88994            crashes after the splash screen on wink  blocker
# 6  418648  configure changes required for building on win...  blocker
# 7  159243  move fontencoding.properties in a sharable loc...  blocker
# 8  230183  preprocessor.pl not executed correctly in /too...  blocker
# 9   31804  open up another window/location while download...  blocker

# %%
df_wrn.head(10)
# Out:
#        id                                        description severity
# 0  460484       spam email with euro symbol crashes shredder  blocker
# 1  673043  the token you submitted does not exist , has e...  blocker
# 2   65661               xpcom plugin instances not destroyed  blocker
# 3  112215  embedding aps (mfcembed & testgtkembed) crashi...  blocker
# 4   92460  testgtkembed missing scroll bars and key based...  blocker
# 5   88994            crashes after the splash screen on wink  blocker
# 6  418648  configure changes required for building on win...  blocker
# 7  159243  move fontencoding.properties in a sharable loc...  blocker
# 8  230183  preprocessor.pl not executed correctly in /too...  blocker
# 9   31804  open up another window/location while download...  blocker

# %%
df_wrn.to_csv('bug_data_cleaned_pratik.csv',index=False)
